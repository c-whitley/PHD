# %%
# %load_ext autoreload

# %autoreload 2

# %%
import SNOM_Import
import os
import matplotlib.pyplot as plt

# %%
file_place = r"C:\Users\Conor\Google Drive\PhD\Reflection_Mode_Images"

# %%
files = [file for file in os.listdir(file_place) if "FTOPO" in file]

# %%
image = SNOM_Import.SNOM_Image(os.path.join(file_place,files[0]))

# %%
image = SNOM_Import.SNOM_Image(os.path.join(file_place, "2249-T000-BSNOM.AFM"))

# %%
plt.imshow(image.image)

# %%
plt.figure(figsize = (10,10))
plt.imshow(image.image)

# %%
image = SNOM_Import.SNOM_File(os.path.join(file_place, "2248-T000"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Google Drive\PhD\Python_Libaries\SNOM_Import.py in import_Header(image_file_name)
#      31
# ---> 32                 with open(image_file_name, mode = "r") as file:
#      33
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Conor\\Google Drive\\PhD\\Reflection_Mode_Images\\2248-T000-HEADR.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-25b73af8e6a1> in <module>
# ----> 1 image = SNOM_Import.SNOM_File(os.path.join(file_place, "2248-T000"))
#
# ~\Google Drive\PhD\Python_Libaries\SNOM_Import.py in __init__(self, filename)
#      11                 # Header
#      12
# ---> 13                 self.HEADR = import_Header(self.fileName + "-HEADR.txt")
#      14
# ...

# %%
plt.imshow(image.FTOPO.image)
plt.axvline(210, c = "r")

# %%
plt.plot(image.FTOPO.image[:,210])

# %%
import matplotlib.pyplot as plt

# %%
import imageio
import scipy.io as sp
import numpy as np

# %%
file_path = r"F:\Data for Wojiech\Cancer adjacent normal breast tissue"

# %%
im = sp.loadmat(os.path.join(file_path, os.listdir(file_path)[0]))

# %%
im = sp.loadmat(os.path.join(file_path, os.listdir(file_path)[0]))

# %%
np.where(np.array(im["wn"]) == 1656)
# Out:
# (array([186], dtype=int64), array([0], dtype=int64))

# %%
np.array(im["wn"]).shape
# Out:
# (223, 1)

# %%
plt.plot(im["image"][150,150,:])

# %%
plt.imshow(im["image"][:,:,186])

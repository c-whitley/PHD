# %% [markdown]
# # Tunnel Modelling Program
#
# ## Introduction/Plan
#
# ### Project Breakdown
# #### Base Program
# * Collect Data on tunnel specifications and car breaking distances ----
# * Create a Monte Carlo procedure for generating random car speeds through the tunnel around a given average speed limit ----
# * Create a car class that holds the position, speed, length, and whether there is a car in front. ----
# * Use the speeds generated to run cars through the tunnel using a for loop for each tick being 1 second, the movement of the cars is shown by the change in position variable.
# * Determine the chance that another car will enter the tunnel per second.
# * Count how many cars exit the tunnel per unit time (e.g. hours), then vary the speed limit and re run the test. Do this for speed limits varying from around 15km/h through to 120km/h (roughly 10 - 70 mph).
# * From this, determine which speed limit allows for the mst cars to pass per hour.
#
# #### Extensions
# * Incorperate different vehicle classes into the mix to see if adding busses and bikes, etc, and determine if the ideal speed limit or the rate of traffic changes.
# * Investigate the ideal number of toll booths that should be used with the new rate of cars travelling through the tunnel, given their average working time.
# * Alter the rate of traffic through the unmanned/manned booths to accommodate those with fast tags.
# * Use the final rate of traffic through the toll booths to determine the maximum revenue that will be collected by the booths.
# * Extend to include both directions of travel through the tunnel.

# %% [markdown]
# Distances Between Cars (Leave 2 seconds. 4 seconds for heavy vehicle/bad weather. Add 1 second for each 1m of trailer length if towing)
# https://www.qld.gov.au/transport/safety/rules/road/distances
#
# Bus length, 14m (45ft)
# Car length, 4.5m

# %% [markdown]
# Testing Speed Limits:
# * 70 mph (31.29m/s)
# * 60 mph (26.82m/s)
# * 50 mph (22.35m/s)
# * 40 mph (17.88m/s)
# * 30 mph (13.41m/s)
# * 20 mph (8.94m/s)
# * 10 mph (4.47m/s)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#Create an array to represent the 3.24km tunel
tunnel = np.zeros(3240)

tunnel_length = 3.24e3
speed_lim = np.array([31.29, 26.82, 22.35, 17.88, 13.41, 8.94, 4.47]) #m/s
spacing = speed_lim * 2
car_length = 4.5
bus_length = 14

length = spacing + car_length
amount = tunnel_length/length

print(amount)

plt.figure()
plt.title("Amount of cars vs speed limit")
plt.plot(speed_lim, amount, color = 'r', linestyle = '-')
plt.xlabel("Speed Limit (m/s)")
plt.ylabel("Number of Cars")
plt.grid(color = 'g')
plt.show()
# Out:
# [ 48.30053667  55.72755418  65.85365854  80.47690015 103.44827586
#  144.77211796 241.07142857]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
'''
Setting the base constants for the model
'''
tunnel_length = 3.24e3 #Length of tunnel (m)
new_car_chance = 0.8   #Probability of a new car entering the tunnel every second
#speed_limits = np.array([4.47, 8.94, 13.41, 17.88, 22.35, 26.82, 31.29]) #m/s
speed_limits = np.array([4.47, 8.94, 13.41, 17.88, 22.35, 26.82, 31.29]) #m/s
speed_limit = speed_limits[0]
avg_car = 4.5    #m
avg_bus = 14    #m
avg_truck = 15    #?????? m

# %%
class Car:
    '''
    Represents a vehicle in the tunnel.
    
    Parameters: 
    - Position: int, Distance past the tunnel entrance in m
    - Speed:    int, Speed of the car in m/s
    - Length:   int, The length of the vehicle in m
    - Front:    Boolean, True or False if the car is within the 2 seconds of the car in front
    - Complete: Boolean, True of False if the car is still in the tunnel, or past the end point
    
    Functions:
    - Check_Front:
        Checks if the car in front is within the 2 second braking window, based on speed limit.
    '''
    def __init__(self, position, speed, length, front, complete):
        self.position = 0 #Immediate position upon creation is 0
        self.speed = speed # Assumes the car is travelling at the speed limit upon entering the tunnel
        self.length = length
        self.front = False # assumes there are no cars immediately in front of any car entering the tunnel
        #self.complete = False
    # End of __init__
#

def change_speed(car):
    '''
    Randomly alters the speed of a car in the tunnel by a small amount
    '''
    rand_param = np.random.normal(0, 0.01, 1)
    new_speed = car.speed + (car.speed * rand_param)
    if (car.speed-speed_limit) < -2.5:
        new_speed = speed_limit - 1
    if (car.speed-speed_limit) > 2.5:
        new_speed = speed_limit + 1
    return new_speed
#
def create_car(speed, length):
    new = Car(0, speed, length, False, False) #Adds a new car to the list, with selected speed and length
    cars.insert(0, new)                   # (Assumes default potision and front and pass)
#
def get_length(avg):
    length = np.random.normal(avg, 1)
    return length
#
def check_front(p1, p2, l2, speed1, speed2):
        '''
        Function checks if there is a car withing the 2 second braking distance.
            - If there is, sets the boolean variable to True, and matches the speed with the car in front.
            - If there isn't, sets the boolean to False and slightly increases the speed of the vehicle.
            
        Parameters:
            - p1: int, Current vehicle position
            - p2: int, Next vehicle position
            - speed2: int, Next vehicle speed
        '''
        if ((p2-l2)-p1)<(speed_limit*2):
            front = True
            speed = speed1 - (speed_limit/10)
        else:
            front = False
            speed = speed1 + (speed_limit/10)    #increases the speed by 1 m/s
        return front, speed
        #
    # End of check_front
#

# %% [markdown]
# ### Simulating traffic over an hour period (Failed)

# %%
cars = []    #initialising cars list
count = 0    #initialising a count variable

for i in range(3600):    #repeats for every second in an hour
    count =+ 1    #increments the count variable
    random = np.random.rand(1)    #generates a random number
    if random < new_car_chance:   #compares to the chance of a new car
        create_car(speed_limit, get_length(avg_car))    #generates a new car
    #
    if i > 0:
        for i in range(len(cars)):
            cars[i].position =+ cars[i].speed
            if cars[i].position > tunnel_length:
                cars.pop(len(cars)-1)
            cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].speed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eec9ee576f83> in <module>
#      13             if cars[i].position > tunnel_length:
#      14                 cars.pop(len(cars)-1)
# ---> 15             cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].speed)
#      16
#
# TypeError: check_front() missing 2 required positional arguments: 'speed1' and 'speed2'

# %% [markdown]
# ### Manually Testing the Runs

# %%
create_car(speed_limit, get_length(avg_car))
cars.pop(len(cars)-1)
for i in range(len(cars)):
    print(cars[i].length)
# Out:
# 2.919948898269654
# 3.6860293569208578

# %%
print(len(cars))
# Out:
# 2

# %%
cars.pop(len(cars)-1)
for i in range(len(cars)):
    print(cars[i].length)
# Out:
# 2.919948898269654

# %%
cars = []
counter = 0
counts = []
car_count = 0
create_car(speed_limit, get_length(avg_car))    #Generates an Initial Car

# %%
counter = counter + 1    #increments the count variable

#
if len(cars) > 0:
    for i in range(len(cars)):    #all cars
        cars[i].position = cars[i].position + cars[i].speed  #Changes Position
        cars[i].speed = change_speed(cars[i])    #Changes Speed Randomly
#

if len(cars) > 1:
    for i in range(len(cars)-1):
            cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].length, cars[i].speed, cars[i+1].speed)
    if cars[len(cars)-1].position > tunnel_length:
        cars.pop(len(cars)-1)
        car_count = car_count + 1
    #
#

random = np.random.rand(1)    #generates a random number
if random < new_car_chance:   #compares to the chance of a new car
    create_car(speed_limit, get_length(avg_car))    #generates a new car
#
if counter >= 60:
    counts.append(car_count)
    car_count = 0
    counter = 0
print(len(cars))
print("Counter = ", counter)
print("Car Count = ", car_count)
print("Counts", counts)
for i in range(len(cars)-1):
    print(cars[i+1].position-cars[i].position)
print("")
for i in range(len(cars)):
    print(cars[i].position, cars[i].speed, cars[i].front)
# Out:
# 2
# Counter =  1
# Car Count =  0
# Counts []
# 4.47
#
# 0 4.47 False
# 4.47 [4.44870533] False

# %%
for i in range(len(cars)-1):
    print(cars[i+1].position-cars[i].position)
# Out:
# 4.47

# %% [markdown]
# ### Distribution Testing

# %%
yData = np.random.normal(0, 0.02, 10000000)

plt.figure()
plt.title("Amount of cars vs speed limit")
plt.hist(yData, 120)
plt.xlabel("Speed Limit (m/s)")
plt.ylabel("Number of Cars")
plt.grid(color = 'g')
plt.show()

# %%
dat_morning = np.random.normal(10, 2, 100000)
dat_afternoon = np.random.normal(18, 2, 100000)

plt.figure()
plt.title("Amount of cars vs speed limit")
plt.hist(dat_morning, 120)
plt.hist(dat_afternoon, 120)
plt.xlabel("Speed Limit (m/s)")
plt.ylabel("Number of Cars")
plt.grid(color = 'g')
xDataplt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9e6709248ebf> in <module>
#       9 plt.ylabel("Number of Cars")
#      10 plt.grid(color = 'g')
# ---> 11 xDataplt.show()
#
# NameError: name 'xDataplt' is not defined

# %%
xData = np.linspace(0,23, 24)
days = np.array([350, 250, 230, 200, 220, 375, 750, 1475, 1975, 1312, 1208, 1300, 1385, 1385, 1350, 1480, 1800, 1875, 1260, 980, 775, 650, 440, 375])
friday = np.array([375, 260, 230, 200, 220, 375, 730, 1500, 2063, 1475, 1375, 1500, 1563, 1565, 1750, 1937, 2313, 2500, 1937, 1450, 1125, 850, 583, 458])
yData = ((6*days) + friday)/7

print("Data From: https://journals.plos.org/plosone/article/figure?id=10.1371/journal.pone.0049171.g004")
plt.figure()
plt.title("Car Distribution Data")
plt.plot(xData, yData, linestyle='-', marker ='x')
plt.xlabel("Speed Limit (m/s)")
plt.ylabel("Number of Cars")
plt.grid(color = 'g')
plt.show()


print("Total = ", sum(yData))
scale = 1.0174238  #25425 / Total Cars in Distribution
print("Scale Factor = ", scale)
print("Scaled Total = ", sum(yData)*scale)
print("")

plt.figure()
plt.title("Scaled Car Distribution Data")
plt.plot(xData, yData*scale, linestyle='-', marker ='x')
plt.xlabel("Speed Limit (m/s)")
plt.ylabel("Number of Cars")
plt.grid(color = 'g')
plt.show()

print("Probabilities of new car every second based on Distribution Data:")
print((yData*scale)/3600)
print("")
hours = yData*scale/3600
seconds = []
for i in range(len(hours)-1):
    temp=(np.linspace(hours[i], hours[i+1], 3600))
    seconds = np.append(seconds, temp)
seconds = np.append(seconds, np.linspace(hours[23], hours[0], 3600))
print(len(seconds))
# Out:
# Data From: https://journals.plos.org/plosone/article/figure?id=10.1371/journal.pone.0049171.g004
# Total =  24104.85714285714
# Scale Factor =  1.0174238
# Scaled Total =  24524.855352742856
# Probabilities of new car every second based on Distribution Data:
# [0.09992555 0.07105817 0.06500208 0.05652354 0.0621759  0.10598165
#  0.21115581 0.41787049 0.56172291 0.37737541 0.34814466 0.37547783
#  0.39861211 0.39869286 0.39768351 0.43672513 0.52942374 0.55514195
#  0.3834315  0.29594113 0.23315962 0.19177631 0.13012527 0.10933268]
#
# 86400

# %% [markdown]
# ### First Attempt at for-looping code and running for a day (WORKED!!):

# %%
import sys
cars = []
counter = 0
counts = []
car_count = 0
create_car(speed_limit, get_length(avg_car))    #Generates an Initial Car

seconds = seconds/seconds.sum()

for inc in range(len(seconds)):
    
    new_car_chance = seconds[inc]
    counter = counter + 1    #increments the count variable
    #
    if len(cars) > 0:
        for i in range(len(cars)):    #all cars
            cars[i].position = cars[i].position + cars[i].speed  #Changes Position
            cars[i].speed = change_speed(cars[i])    #Changes Speed Randomly
        #
    #
    if len(cars) > 1:
        for i in range(len(cars)-1):
            cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].length, cars[i].speed, cars[i+1].speed)
        #
        if cars[len(cars)-1].position > tunnel_length:
            cars.pop(len(cars)-1)
            car_count = car_count + 1
        
        no_crashes = True
        i = 0
        
        while no_crashes:

            if (cars[i+1].position-cars[i].position) < cars[i+1].length:
                print("Simulation Halted!")
                print("There was a crash, please retry or consult Tom")
                no_crashes = False
            i += 1
                #for i in range(len(cars)-1):
                #   pass
                #print(cars[i+1].position-cars[i+1].length-cahere:rs[i].position)
                #exit()
    #
    
    random = np.random.rand(1)/len(seconds)    #generates a random number
    if random < new_car_chance:   #compares to the chance of a new car
        create_car(speed_limit, get_length(avg_car))    #generates a new car
    #
    if counter >= 60:
        counts.append(car_count)
        car_count = 0
        counter = 0
    #
#
print("Simulation Completed!")
print("counts = ", counts)
print("Sum = ", sum(counts))
print("Length = ", len(counts))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-169-23f35cbbd0be> in <module>
#      32         while no_crashes:
#      33
# ---> 34             if (cars[i+1].position-cars[i].position) < cars[i+1].length:
#      35                 print("Simulation Halted!")
#      36                 print("There was a crash, please retry or consult Tom")
#
# IndexError: list index out of range

# %%
from scipy.interpolate import UnivariateSpline

plt.figure(figsize=(16, 12))
plt.title("Amount of cars per minute")
plt.plot(np.linspace(0, 1440, 1440), counts, linestyle='', marker ='x')
plt.xlabel("Minute of Day")
plt.ylabel("Number of Cars")
plt.xticks([0,60,120,180,240,300,360,420,480,540,600,660,720,780,840,900,960,1020,1080,1140,1200,1260,1320,1380,1440])
plt.grid(color = 'g')

s = UnivariateSpline(np.linspace(0,1440,1440), counts, s=13500)
xs = np.linspace(0, 1440, 1440)
ys = s(xs)
plt.plot(xs, ys)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-89555cf02a0e> in <module>
#       3 plt.figure(figsize=(16, 12))
#       4 plt.title("Amount of cars per minute")
# ----> 5 plt.plot(np.linspace(0, 1440, 1440), counts, linestyle='', marker ='x')
#       6 plt.xlabel("Minute of Day")
#       7 plt.ylabel("Number of Cars")
#
# ~/miniconda3/envs/NN/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/miniconda3/envs/NN/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/miniconda3/envs/NN/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/miniconda3/envs/NN/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/miniconda3/envs/NN/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1440,) and (0,)

# %%
import sys
count_list = []
for attempt in range(5):
    cars = []
    counter = 0
    counts = []
    car_count = 0
    create_car(speed_limit, get_length(avg_car))    #Generates an Initial Car
    for inc in range(len(seconds)):
        new_car_chance = seconds[inc]
        counter = counter + 1    #increments the count variable
        #
        if len(cars) > 0:
            for i in range(len(cars)):    #all cars
                cars[i].position = cars[i].position + cars[i].speed  #Changes Position
                cars[i].speed = change_speed(cars[i])    #Changes Speed Randomly
            #
        #
        if len(cars) > 1:
            for i in range(len(cars)-1):
                    cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].length, cars[i].speed, cars[i+1].speed)
            #
            if cars[len(cars)-1].position > tunnel_length:
                cars.pop(len(cars)-1)
                car_count = car_count + 1
            #
            for i in range(len(cars)-1):
                if ((cars[i+1].position-cars[i+1].length)-cars[i].position)<0:
                    print("Simulation Halted!")
                    print("There was a crash, please retry or consult Tom")
                    for i in range(len(cars)-1):
                        print(cars[i+1].position-cars[i].position)
                    exit()
        #
        
        random = np.random.rand(1)    #generates a random number
        if random < new_car_chance:   #compares to the chance of a new car
            create_car(speed_limit, get_length(avg_car))    #generates a new car
        #
        if counter >= 60:
            counts.append(car_count)
            car_count = 0
            counter = 0
        #
    #
    count_list.append(counts)
print("Simulation Completed!")
# Out:
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [18.74378134]
# [10.99908576]
# [20.91481105]
# [60.83749828]
# [13.25055828]
# [23.53738271]
# [24.48895916]
# [16.29418212]
# [25.59513947]
# [21.2613866]
# [5.01541689]
# [17.4994648]
# [-1.237747]
# [8.8232313]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [17.92476336]
# [10.92163103]
# [21.62975259]
# [60.24627686]
# [12.76792852]
# [23.53738271]
# [24.91987328]
# [17.15730456]
# [24.87929177]
# [20.23940433]
# [5.19651828]
# [17.04558661]
# [-3.4151768]
# [9.83739489]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [18.78157803]
# [10.85898583]
# [20.83558313]
# [61.28152268]
# [12.1385021]
# [23.48080046]
# [25.43101391]
# [16.29692678]
# [25.92048227]
# [18.3637409]
# [6.18016177]
# [15.75886653]
# [-4.77077613]
# [10.47045811]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.59616853]
# [10.7174887]
# [20.02427859]
# [62.39430083]
# [11.42733878]
# [23.40420273]
# [26.0374723]
# [15.36321599]
# [26.98884373]
# [15.59787065]
# [8.08434098]
# [13.51072713]
# [-5.20066371]
# [10.66817966]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [18.52782579]
# [10.7174887]
# [20.83014703]
# [61.58843239]
# [12.75874662]
# [23.23743922]
# [24.87282798]
# [16.17113947]
# [26.18092025]
# [13.80381933]
# [11.03508443]
# [10.25686637]
# [-4.74266622]
# [10.41262309]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.07527869]
# [10.59006294]
# [21.63994794]
# [60.66644621]
# [12.45090474]
# [23.23743922]
# [25.21243834]
# [17.11825964]
# [25.36451913]
# [11.90097909]
# [12.46759526]
# [7.75372828]
# [-3.42021499]
# [9.7390908]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.60519636]
# [10.53901296]
# [20.74429749]
# [61.45622137]
# [12.05196248]
# [23.41174999]
# [25.4789185]
# [16.2866358]
# [26.34659748]
# [9.91351195]
# [13.16420773]
# [5.10444294]
# [-1.20583652]
# [8.6465979]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.19390948]
# [18.59978316]
# [10.32529889]
# [20.52097428]
# [61.60131949]
# [12.99294982]
# [23.75773751]
# [24.30173214]
# [16.05943317]
# [25.57389775]
# [8.7920395]
# [12.0077249]
# [-0.20787595]
# [3.1390064]
# [7.86389492]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.70778662]
# [19.03062616]
# [10.27683665]
# [21.41153074]
# [60.70332773]
# [12.61800435]
# [23.75773751]
# [24.70397041]
# [16.78140367]
# [23.18969152]
# [10.20197272]
# [10.24646331]
# [-2.93186064]
# [5.280802]
# [8.19172442]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.10479107]
# [19.48823863]
# [10.24395745]
# [20.64692608]
# [61.53398433]
# [12.25800906]
# [23.68530721]
# [25.15039489]
# [15.93674818]
# [22.30196858]
# [11.75588467]
# [7.46547252]
# [-3.71105886]
# [5.5355952]
# [8.91305516]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.50949804]
# [19.90587229]
# [10.16888668]
# [19.9000844]
# [62.38456701]
# [11.8970373]
# [23.67670167]
# [25.41738982]
# [15.24674763]
# [21.41354866]
# [12.43494582]
# [4.60155432]
# [-4.41832443]
# [5.78386103]
# [10.06208185]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.84104939]
# [18.68350984]
# [10.16888668]
# [20.73406321]
# [61.5505882]
# [13.15591336]
# [23.68508216]
# [24.15013328]
# [16.15432679]
# [20.44359646]
# [12.20359492]
# [1.85563264]
# [-5.10551959]
# [6.89126126]
# [10.76669789]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.70737998]
# [19.10448266]
# [10.11319354]
# [21.61205836]
# [60.74977244]
# [12.7134543]
# [23.68508216]
# [24.55871885]
# [17.16850679]
# [19.31349651]
# [11.1973921]
# [-0.92482217]
# [-5.79055446]
# [8.9176797]
# [11.007921]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.70737998]
# [19.10448266]
# [10.11319354]
# [21.61205836]
# [60.74977244]
# [12.7134543]
# [23.68508216]
# [24.55871885]
# [17.16850679]
# [19.31349651]
# [11.1973921]
# [-0.92482217]
# [-5.79055446]
# [8.9176797]
# [11.007921]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.1744215]
# [19.43299128]
# [9.97378637]
# [20.95591539]
# [61.57474329]
# [12.28497253]
# [23.77828307]
# [24.85372033]
# [16.3838153]
# [20.05726037]
# [9.26603376]
# [-3.67294257]
# [-4.74883958]
# [10.14670828]
# [10.75240556]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.1744215]
# [19.43299128]
# [9.97378637]
# [20.95591539]
# [61.57474329]
# [12.28497253]
# [23.77828307]
# [24.85372033]
# [16.3838153]
# [20.05726037]
# [9.26603376]
# [-3.67294257]
# [-4.74883958]
# [10.14670828]
# [10.75240556]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.6861378]
# [19.84256516]
# [9.82867222]
# [20.21867554]
# [62.48325393]
# [11.84117431]
# [23.89721426]
# [25.13058613]
# [15.57844314]
# [20.82955448]
# [6.43098559]
# [-6.45760259]
# [-2.81514635]
# [11.44141869]
# [9.92626204]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [90.6861378]
# [19.84256516]
# [9.82867222]
# [20.21867554]
# [62.48325393]
# [11.84117431]
# [23.89721426]
# [25.13058613]
# [15.57844314]
# [20.82955448]
# [6.43098559]
# [-6.45760259]
# [-2.81514635]
# [11.44141869]
# [9.92626204]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [91.09681315]
# [18.58254811]
# [9.82867222]
# [21.08498303]
# [61.61694644]
# [13.04840228]
# [24.1894013]
# [23.63117112]
# [16.30156838]
# [19.21242924]
# [5.20583599]
# [-7.23245299]
# [-1.95891577]
# [12.72758376]
# [8.66847554]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [91.09681315]
# [18.58254811]
# [9.82867222]
# [21.08498303]
# [61.61694644]
# [13.04840228]
# [24.1894013]
# [23.63117112]
# [16.30156838]
# [19.21242924]
# [5.20583599]
# [-7.23245299]
# [-1.95891577]
# [12.72758376]
# [8.66847554]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.83412869]
# [19.05474859]
# [9.80791223]
# [21.79590514]
# [60.88920111]
# [12.613785]
# [24.1894013]
# [24.07557319]
# [17.07508214]
# [16.64691592]
# [3.9259854]
# [-7.94499334]
# [-0.16461933]
# [12.98246165]
# [7.98927353]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [89.83412869]
# [19.05474859]
# [9.80791223]
# [21.79590514]
# [60.88920111]
# [12.613785]
# [24.1894013]
# [24.07557319]
# [17.07508214]
# [16.64691592]
# [3.9259854]
# [-7.94499334]
# [-0.16461933]
# [12.98246165]
# [7.98927353]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [63.91719756]
# [90.33325481]
# [19.53532549]
# [9.69011335]
# [20.93400101]
# [61.81739635]
# [12.16762626]
# [24.2271923]
# [24.34374446]
# [16.28708337]
# [14.82001624]
# [2.69661337]
# [-8.65760276]
# [2.4842467]
# [12.40054766]
# [7.7117181]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.43825238]
# [90.87815869]
# [19.97828928]
# [9.59100677]
# [20.08415733]
# [62.78595123]
# [11.57151161]
# [24.3169279]
# [24.44383919]
# [15.66702968]
# [12.04406808]
# [1.52015891]
# [-9.39721526]
# [6.00881765]
# [10.90472712]
# [7.89420805]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.12566397]
# [91.34195519]
# [18.4325813]
# [9.59100677]
# [21.05547034]
# [61.81463822]
# [12.91551687]
# [24.32296119]
# [23.09380065]
# [16.59239437]
# [8.37954822]
# [0.35580519]
# [-8.38770637]
# [8.67249167]
# [8.45353884]
# [8.51015074]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.16993367]
# [91.34195519]
# [18.78022769]
# [9.66811241]
# [21.94092121]
# [60.90184654]
# [12.51810564]
# [24.32296119]
# [23.58299261]
# [16.52571542]
# [4.77926101]
# [-0.80586181]
# [-7.37938745]
# [11.23729974]
# [6.13304479]
# [9.48887037]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.16993367]
# [91.34195519]
# [18.78022769]
# [9.66811241]
# [21.94092121]
# [60.90184654]
# [12.51810564]
# [24.32296119]
# [23.58299261]
# [16.52571542]
# [4.77926101]
# [-0.80586181]
# [-7.37938745]
# [11.23729974]
# [6.13304479]
# [9.48887037]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.15096959]
# [91.37453354]
# [19.14970564]
# [9.6168671]
# [21.18240006]
# [61.79650999]
# [11.96682595]
# [24.41886274]
# [24.12179659]
# [15.36233409]
# [1.33155082]
# [-0.0668596]
# [-7.37714389]
# [12.84485931]
# [4.7732959]
# [9.99081135]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.15096959]
# [91.37453354]
# [19.14970564]
# [9.6168671]
# [21.18240006]
# [61.79650999]
# [11.96682595]
# [24.41886274]
# [24.12179659]
# [15.36233409]
# [1.33155082]
# [-0.0668596]
# [-7.37714389]
# [12.84485931]
# [4.7732959]
# [9.99081135]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.20685512]
# [91.23659019]
# [19.60266268]
# [9.60315019]
# [20.47332364]
# [62.6257236]
# [11.39055791]
# [24.55262327]
# [24.64835265]
# [13.33065685]
# [-2.15679151]
# [0.70431584]
# [-6.56796194]
# [13.70268439]
# [4.26355008]
# [9.99251044]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.20685512]
# [91.23659019]
# [19.60266268]
# [9.60315019]
# [20.47332364]
# [62.6257236]
# [11.39055791]
# [24.55262327]
# [24.64835265]
# [13.33065685]
# [-2.15679151]
# [0.70431584]
# [-6.56796194]
# [13.70268439]
# [4.26355008]
# [9.99251044]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.31235017]
# [9.60315019]
# [21.41838698]
# [61.68066027]
# [12.69049552]
# [24.58429986]
# [23.31673846]
# [12.37192946]
# [-4.09206412]
# [-0.13243309]
# [-4.91638679]
# [13.71550469]
# [4.6503587]
# [9.51841553]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.31235017]
# [9.60315019]
# [21.41838698]
# [61.68066027]
# [12.69049552]
# [24.58429986]
# [23.31673846]
# [12.37192946]
# [-4.09206412]
# [-0.13243309]
# [-4.91638679]
# [13.71550469]
# [4.6503587]
# [9.51841553]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.31235017]
# [9.60315019]
# [21.41838698]
# [61.68066027]
# [12.69049552]
# [24.58429986]
# [23.31673846]
# [12.37192946]
# [-4.09206412]
# [-0.13243309]
# [-4.91638679]
# [13.71550469]
# [4.6503587]
# [9.51841553]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.83243642]
# [9.49538974]
# [22.41753718]
# [60.71163788]
# [12.2480419]
# [24.58429986]
# [23.77592981]
# [10.56871798]
# [-6.08938434]
# [-0.95038549]
# [-2.37121111]
# [12.79269862]
# [5.86801493]
# [8.71492732]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.83243642]
# [9.49538974]
# [22.41753718]
# [60.71163788]
# [12.2480419]
# [24.58429986]
# [23.77592981]
# [10.56871798]
# [-6.08938434]
# [-0.95038549]
# [-2.37121111]
# [12.79269862]
# [5.86801493]
# [8.71492732]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.39411721]
# [91.02638245]
# [18.83243642]
# [9.49538974]
# [22.41753718]
# [60.71163788]
# [12.2480419]
# [24.58429986]
# [23.77592981]
# [10.56871798]
# [-6.08938434]
# [-0.95038549]
# [-2.37121111]
# [12.79269862]
# [5.86801493]
# [8.71492732]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.38016105]
# [91.05810439]
# [19.2861902]
# [9.48211511]
# [21.49254179]
# [61.65663038]
# [11.80783458]
# [24.4174022]
# [24.35132317]
# [7.83180097]
# [-8.09109102]
# [-0.01904267]
# [-0.59139099]
# [10.96916298]
# [7.00454974]
# [8.42122565]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.38016105]
# [91.05810439]
# [19.2861902]
# [9.48211511]
# [21.49254179]
# [61.65663038]
# [11.80783458]
# [24.4174022]
# [24.35132317]
# [7.83180097]
# [-8.09109102]
# [-0.01904267]
# [-0.59139099]
# [10.96916298]
# [7.00454974]
# [8.42122565]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.38016105]
# [91.05810439]
# [19.2861902]
# [9.48211511]
# [21.49254179]
# [61.65663038]
# [11.80783458]
# [24.4174022]
# [24.35132317]
# [7.83180097]
# [-8.09109102]
# [-0.01904267]
# [-0.59139099]
# [10.96916298]
# [7.00454974]
# [8.42122565]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.15860167]
# [91.14164779]
# [19.77998816]
# [9.41037481]
# [20.61813222]
# [62.67147862]
# [11.37488403]
# [24.17297265]
# [24.0720059]
# [5.07266931]
# [-10.10322969]
# [0.93380583]
# [2.08041541]
# [8.19722194]
# [8.21484184]
# [8.48767275]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.85539713]
# [91.3543078]
# [18.39062921]
# [9.41037481]
# [21.55680395]
# [61.73280689]
# [12.9121138]
# [23.94794575]
# [22.83807528]
# [2.31687487]
# [-10.31970748]
# [0.05843116]
# [4.88752007]
# [5.29134329]
# [9.41770162]
# [9.03210179]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.85539713]
# [91.3543078]
# [18.93897618]
# [9.22868437]
# [22.57819008]
# [60.82732337]
# [12.42955463]
# [23.94794575]
# [22.51000384]
# [-0.49167711]
# [-10.51495218]
# [-0.78757363]
# [7.61136146]
# [3.3269792]
# [10.65655487]
# [9.02703229]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.85539713]
# [91.3543078]
# [18.93897618]
# [9.22868437]
# [22.57819008]
# [60.82732337]
# [12.42955463]
# [23.94794575]
# [22.51000384]
# [-0.49167711]
# [-10.51495218]
# [-0.78757363]
# [7.61136146]
# [3.3269792]
# [10.65655487]
# [9.02703229]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.85539713]
# [91.3543078]
# [18.93897618]
# [9.22868437]
# [22.57819008]
# [60.82732337]
# [12.42955463]
# [23.94794575]
# [22.51000384]
# [-0.49167711]
# [-10.51495218]
# [-0.78757363]
# [7.61136146]
# [3.3269792]
# [10.65655487]
# [9.02703229]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.89782267]
# [91.2878442]
# [19.62151403]
# [9.06403937]
# [21.72117779]
# [61.87676705]
# [11.81017545]
# [23.9907966]
# [21.26543538]
# [-3.27878626]
# [-10.69311126]
# [0.05534771]
# [8.56958397]
# [2.32161222]
# [11.80200661]
# [8.67549766]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.89782267]
# [91.2878442]
# [19.62151403]
# [9.06403937]
# [21.72117779]
# [61.87676705]
# [11.81017545]
# [23.9907966]
# [21.26543538]
# [-3.27878626]
# [-10.69311126]
# [0.05534771]
# [8.56958397]
# [2.32161222]
# [11.80200661]
# [8.67549766]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.87063382]
# [91.30225343]
# [20.36445546]
# [8.81144524]
# [20.87184215]
# [62.77367534]
# [11.32015473]
# [24.09740076]
# [19.02880993]
# [-6.06146227]
# [-10.8085026]
# [0.88102196]
# [9.50887606]
# [2.24954538]
# [12.02196965]
# [8.78127842]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.87063382]
# [91.30225343]
# [20.36445546]
# [8.81144524]
# [20.87184215]
# [62.77367534]
# [11.32015473]
# [24.09740076]
# [19.02880993]
# [-6.06146227]
# [-10.8085026]
# [0.88102196]
# [9.50887606]
# [2.24954538]
# [12.02196965]
# [8.78127842]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.74897535]
# [91.31835907]
# [18.21932954]
# [9.70544524]
# [21.7809268]
# [61.86459069]
# [12.60394481]
# [24.21547191]
# [15.94935607]
# [-7.27786965]
# [-10.8085026]
# [0.88721026]
# [9.56419929]
# [3.0332027]
# [11.38572918]
# [9.33308795]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.74897535]
# [91.31835907]
# [18.21932954]
# [9.70544524]
# [21.7809268]
# [61.86459069]
# [12.60394481]
# [24.21547191]
# [15.94935607]
# [-7.27786965]
# [-10.8085026]
# [0.88721026]
# [9.56419929]
# [3.0332027]
# [11.38572918]
# [9.33308795]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.74897535]
# [91.31835907]
# [17.78750394]
# [10.64439001]
# [22.65070168]
# [60.96370457]
# [12.12793688]
# [24.21547191]
# [13.77939311]
# [-8.36022374]
# [-10.86989986]
# [1.75227894]
# [8.69846829]
# [4.77437712]
# [10.70221505]
# [9.50120722]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.74897535]
# [91.31835907]
# [17.78750394]
# [10.64439001]
# [22.65070168]
# [60.96370457]
# [12.12793688]
# [24.21547191]
# [13.77939311]
# [-8.36022374]
# [-10.86989986]
# [1.75227894]
# [8.69846829]
# [4.77437712]
# [10.70221505]
# [9.50120722]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.76440702]
# [91.31947003]
# [17.19312667]
# [11.62938296]
# [21.7557002]
# [61.7826492]
# [11.78741954]
# [24.1969733]
# [10.7150705]
# [-9.45690753]
# [-10.94155622]
# [2.65448116]
# [7.82487403]
# [7.4414727]
# [9.98943158]
# [9.16895399]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.76440702]
# [91.31947003]
# [17.19312667]
# [11.62938296]
# [21.7557002]
# [61.7826492]
# [11.78741954]
# [24.1969733]
# [10.7150705]
# [-9.45690753]
# [-10.94155622]
# [2.65448116]
# [7.82487403]
# [7.4414727]
# [9.98943158]
# [9.16895399]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.86503857]
# [91.16032501]
# [16.74523324]
# [12.58405805]
# [20.90004649]
# [62.573727]
# [11.45961565]
# [24.29864879]
# [6.71945613]
# [-10.62099705]
# [-10.97900168]
# [3.49654059]
# [7.00548357]
# [11.03832283]
# [9.21890418]
# [8.3800598]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.86503857]
# [91.16032501]
# [16.74523324]
# [12.58405805]
# [20.90004649]
# [62.573727]
# [11.45961565]
# [24.29864879]
# [6.71945613]
# [-10.62099705]
# [-10.97900168]
# [3.49654059]
# [7.00548357]
# [11.03832283]
# [9.21890418]
# [8.3800598]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.01701721]
# [90.90080926]
# [16.14853214]
# [11.93687914]
# [21.82629579]
# [61.64747771]
# [12.72346223]
# [23.75335787]
# [2.53127465]
# [-10.04537123]
# [-10.97900168]
# [2.57336235]
# [8.82266181]
# [12.85515402]
# [7.66270442]
# [7.9845839]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.01701721]
# [90.90080926]
# [16.14853214]
# [11.93687914]
# [21.82629579]
# [61.64747771]
# [12.72346223]
# [23.75335787]
# [2.53127465]
# [-10.04537123]
# [-10.97900168]
# [2.57336235]
# [8.82266181]
# [12.85515402]
# [7.66270442]
# [7.9845839]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.01701721]
# [90.90080926]
# [17.15677665]
# [11.38893265]
# [22.68526537]
# [60.72393459]
# [12.32773776]
# [23.94841891]
# [-1.61281453]
# [-9.38436168]
# [-11.0255203]
# [1.6730521]
# [11.52477785]
# [13.72988128]
# [6.12331702]
# [8.03601515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.01701721]
# [90.90080926]
# [17.15677665]
# [11.38893265]
# [22.68526537]
# [60.72393459]
# [12.32773776]
# [23.94841891]
# [-1.61281453]
# [-9.38436168]
# [-11.0255203]
# [1.6730521]
# [11.52477785]
# [13.72988128]
# [6.12331702]
# [8.03601515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.01701721]
# [90.90080926]
# [17.15677665]
# [11.38893265]
# [22.68526537]
# [60.72393459]
# [12.32773776]
# [23.94841891]
# [-1.61281453]
# [-9.38436168]
# [-11.0255203]
# [1.6730521]
# [11.52477785]
# [13.72988128]
# [6.12331702]
# [8.03601515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.9300797]
# [90.96850399]
# [18.09112725]
# [10.90902485]
# [21.81224849]
# [61.5304459]
# [11.92468933]
# [23.4581248]
# [-4.4199833]
# [-10.22257582]
# [-11.05954874]
# [3.43929467]
# [12.39509099]
# [13.78972264]
# [4.49519483]
# [8.55369515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.9300797]
# [90.96850399]
# [18.09112725]
# [10.90902485]
# [21.81224849]
# [61.5304459]
# [11.92468933]
# [23.4581248]
# [-4.4199833]
# [-10.22257582]
# [-11.05954874]
# [3.43929467]
# [12.39509099]
# [13.78972264]
# [4.49519483]
# [8.55369515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.9300797]
# [90.96850399]
# [18.09112725]
# [10.90902485]
# [21.81224849]
# [61.5304459]
# [11.92468933]
# [23.4581248]
# [-4.4199833]
# [-10.22257582]
# [-11.05954874]
# [3.43929467]
# [12.39509099]
# [13.78972264]
# [4.49519483]
# [8.55369515]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.88470662]
# [91.03128969]
# [17.21579808]
# [12.12907516]
# [21.13499921]
# [62.30129054]
# [11.47831801]
# [22.11150597]
# [-7.29073902]
# [-11.06052575]
# [-11.08729732]
# [6.17274853]
# [13.24913686]
# [12.98262433]
# [2.77682947]
# [9.50100588]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.88470662]
# [91.03128969]
# [17.21579808]
# [12.12907516]
# [21.13499921]
# [62.30129054]
# [11.47831801]
# [22.11150597]
# [-7.29073902]
# [-11.06052575]
# [-11.08729732]
# [6.17274853]
# [13.24913686]
# [12.98262433]
# [2.77682947]
# [9.50100588]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.88470662]
# [91.03128969]
# [17.21579808]
# [12.12907516]
# [21.13499921]
# [62.30129054]
# [11.47831801]
# [22.11150597]
# [-7.29073902]
# [-11.06052575]
# [-11.08729732]
# [6.17274853]
# [13.24913686]
# [12.98262433]
# [2.77682947]
# [9.50100588]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [16.33545766]
# [11.76219319]
# [22.16254659]
# [61.27374315]
# [12.79258865]
# [19.88444078]
# [-10.15807756]
# [-10.17439267]
# [-11.08729732]
# [7.93076677]
# [14.20181026]
# [11.29451874]
# [1.93497414]
# [10.06715183]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [16.33545766]
# [11.76219319]
# [22.16254659]
# [61.27374315]
# [12.79258865]
# [19.88444078]
# [-10.15807756]
# [-10.17439267]
# [-11.08729732]
# [7.93076677]
# [14.20181026]
# [11.29451874]
# [1.93497414]
# [10.06715183]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [16.33545766]
# [11.76219319]
# [22.16254659]
# [61.27374315]
# [12.79258865]
# [19.88444078]
# [-10.15807756]
# [-10.17439267]
# [-11.08729732]
# [7.93076677]
# [14.20181026]
# [11.29451874]
# [1.93497414]
# [10.06715183]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [17.13963514]
# [11.39538822]
# [23.16391212]
# [60.28032072]
# [12.34727304]
# [18.49467875]
# [-13.01921147]
# [-9.23763954]
# [-11.13459723]
# [10.62395391]
# [15.0894689]
# [8.76191618]
# [2.03300459]
# [10.17440257]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [17.13963514]
# [11.39538822]
# [23.16391212]
# [60.28032072]
# [12.34727304]
# [18.49467875]
# [-13.01921147]
# [-9.23763954]
# [-11.13459723]
# [10.62395391]
# [15.0894689]
# [8.76191618]
# [2.03300459]
# [10.17440257]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.83996362]
# [91.0553864]
# [17.13963514]
# [11.39538822]
# [23.16391212]
# [60.28032072]
# [12.34727304]
# [18.49467875]
# [-13.01921147]
# [-9.23763954]
# [-11.13459723]
# [10.62395391]
# [15.0894689]
# [8.76191618]
# [2.03300459]
# [10.17440257]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.78417881]
# [91.08639016]
# [17.95520625]
# [10.95775925]
# [22.32413878]
# [61.27488955]
# [11.75483434]
# [16.16294788]
# [-13.98361073]
# [-10.1020092]
# [-10.33306159]
# [13.31130691]
# [15.0767367]
# [6.26926245]
# [3.08176164]
# [9.71449982]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.78417881]
# [91.08639016]
# [17.95520625]
# [10.95775925]
# [22.32413878]
# [61.27488955]
# [11.75483434]
# [16.16294788]
# [-13.98361073]
# [-10.1020092]
# [-10.33306159]
# [13.31130691]
# [15.0767367]
# [6.26926245]
# [3.08176164]
# [9.71449982]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.78417881]
# [91.08639016]
# [17.95520625]
# [10.95775925]
# [22.32413878]
# [61.27488955]
# [11.75483434]
# [16.16294788]
# [-13.98361073]
# [-10.1020092]
# [-10.33306159]
# [13.31130691]
# [15.0767367]
# [6.26926245]
# [3.08176164]
# [9.71449982]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.58392604]
# [91.21317398]
# [17.00838842]
# [12.26649443]
# [21.3939707]
# [62.30904409]
# [11.20620723]
# [12.88601447]
# [-14.85246207]
# [-11.02680558]
# [-8.65761635]
# [16.08216699]
# [14.09386808]
# [3.8088461]
# [4.96485166]
# [8.81318381]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.58392604]
# [91.21317398]
# [17.00838842]
# [12.26649443]
# [21.3939707]
# [62.30904409]
# [11.20620723]
# [12.88601447]
# [-14.85246207]
# [-11.02680558]
# [-8.65761635]
# [16.08216699]
# [14.09386808]
# [3.8088461]
# [4.96485166]
# [8.81318381]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.58392604]
# [91.21317398]
# [17.00838842]
# [12.26649443]
# [21.3939707]
# [62.30904409]
# [11.20620723]
# [12.88601447]
# [-14.85246207]
# [-11.02680558]
# [-8.65761635]
# [16.08216699]
# [14.09386808]
# [3.8088461]
# [4.96485166]
# [8.81318381]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.0973959]
# [11.78350087]
# [22.11085948]
# [61.59215531]
# [12.52675008]
# [8.70858773]
# [-15.72960313]
# [-10.18678062]
# [-7.78173516]
# [18.83438927]
# [12.1890956]
# [1.325977]
# [6.91576751]
# [8.35048973]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.0973959]
# [11.78350087]
# [22.11085948]
# [61.59215531]
# [12.52675008]
# [8.70858773]
# [-15.72960313]
# [-10.18678062]
# [-7.78173516]
# [18.83438927]
# [12.1890956]
# [1.325977]
# [6.91576751]
# [8.35048973]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.0973959]
# [11.78350087]
# [22.11085948]
# [61.59215531]
# [12.52675008]
# [8.70858773]
# [-15.72960313]
# [-10.18678062]
# [-7.78173516]
# [18.83438927]
# [12.1890956]
# [1.325977]
# [6.91576751]
# [8.35048973]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.92475844]
# [11.46742934]
# [22.78873362]
# [60.75861951]
# [11.27712073]
# [6.31443623]
# [-16.60439391]
# [-9.43390109]
# [-5.90612871]
# [21.58802109]
# [9.32849446]
# [-1.15416565]
# [8.86134284]
# [8.37565567]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.92475844]
# [11.46742934]
# [22.78873362]
# [60.75861951]
# [11.27712073]
# [6.31443623]
# [-16.60439391]
# [-9.43390109]
# [-5.90612871]
# [21.58802109]
# [9.32849446]
# [-1.15416565]
# [8.86134284]
# [8.37565567]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.92475844]
# [11.46742934]
# [22.78873362]
# [60.75861951]
# [11.27712073]
# [6.31443623]
# [-16.60439391]
# [-9.43390109]
# [-5.90612871]
# [21.58802109]
# [9.32849446]
# [-1.15416565]
# [8.86134284]
# [8.37565567]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.56825123]
# [91.23872887]
# [16.92475844]
# [11.46742934]
# [22.78873362]
# [60.75861951]
# [11.27712073]
# [6.31443623]
# [-16.60439391]
# [-9.43390109]
# [-5.90612871]
# [21.58802109]
# [9.32849446]
# [-1.15416565]
# [8.86134284]
# [8.37565567]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.42221714]
# [91.26119577]
# [17.70427978]
# [11.21953317]
# [21.81524768]
# [61.54429313]
# [9.09364353]
# [4.02707343]
# [-15.81322753]
# [-10.38713216]
# [-3.09570553]
# [22.62482899]
# [7.22256375]
# [-1.94223495]
# [9.19076271]
# [8.76907064]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.42221714]
# [91.26119577]
# [17.70427978]
# [11.21953317]
# [21.81524768]
# [61.54429313]
# [9.09364353]
# [4.02707343]
# [-15.81322753]
# [-10.38713216]
# [-3.09570553]
# [22.62482899]
# [7.22256375]
# [-1.94223495]
# [9.19076271]
# [8.76907064]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.42221714]
# [91.26119577]
# [17.70427978]
# [11.21953317]
# [21.81524768]
# [61.54429313]
# [9.09364353]
# [4.02707343]
# [-15.81322753]
# [-10.38713216]
# [-3.09570553]
# [22.62482899]
# [7.22256375]
# [-1.94223495]
# [9.19076271]
# [8.76907064]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.42221714]
# [91.26119577]
# [17.70427978]
# [11.21953317]
# [21.81524768]
# [61.54429313]
# [9.09364353]
# [4.02707343]
# [-15.81322753]
# [-10.38713216]
# [-3.09570553]
# [22.62482899]
# [7.22256375]
# [-1.94223495]
# [9.19076271]
# [8.76907064]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.08569491]
# [91.36669779]
# [16.77464236]
# [12.48852029]
# [21.014299]
# [62.2626684]
# [6.14313707]
# [1.6790737]
# [-15.05063991]
# [-11.33390763]
# [0.62934231]
# [22.81267698]
# [5.0443589]
# [-1.83503456]
# [8.66343082]
# [9.6120507]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.08569491]
# [91.36669779]
# [16.77464236]
# [12.48852029]
# [21.014299]
# [62.2626684]
# [6.14313707]
# [1.6790737]
# [-15.05063991]
# [-11.33390763]
# [0.62934231]
# [22.81267698]
# [5.0443589]
# [-1.83503456]
# [8.66343082]
# [9.6120507]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.08569491]
# [91.36669779]
# [16.77464236]
# [12.48852029]
# [21.014299]
# [62.2626684]
# [6.14313707]
# [1.6790737]
# [-15.05063991]
# [-11.33390763]
# [0.62934231]
# [22.81267698]
# [5.0443589]
# [-1.83503456]
# [8.66343082]
# [9.6120507]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.23195985]
# [91.56736822]
# [15.86120955]
# [12.05501772]
# [21.99788486]
# [60.38508254]
# [4.81795461]
# [1.00425616]
# [-15.93815949]
# [-10.44638805]
# [3.36360477]
# [22.12811585]
# [2.87609712]
# [-1.66522891]
# [8.93717442]
# [10.01596831]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.23195985]
# [91.56736822]
# [15.86120955]
# [12.05501772]
# [21.99788486]
# [60.38508254]
# [4.81795461]
# [1.00425616]
# [-15.93815949]
# [-10.44638805]
# [3.36360477]
# [22.12811585]
# [2.87609712]
# [-1.66522891]
# [8.93717442]
# [10.01596831]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [67.23195985]
# [91.56736822]
# [15.86120955]
# [12.05501772]
# [21.99788486]
# [60.38508254]
# [4.81795461]
# [1.00425616]
# [-15.93815949]
# [-10.44638805]
# [3.36360477]
# [22.12811585]
# [2.87609712]
# [-1.66522891]
# [8.93717442]
# [10.01596831]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.75047462]
# [91.56736822]
# [16.69674061]
# [11.72544587]
# [22.97242218]
# [57.46352753]
# [3.60783048]
# [0.36000721]
# [-16.86367802]
# [-9.62584606]
# [7.01615556]
# [20.60415702]
# [0.69797597]
# [-1.54803547]
# [10.10858759]
# [9.98274867]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.75047462]
# [91.56736822]
# [16.69674061]
# [11.72544587]
# [22.97242218]
# [57.46352753]
# [3.60783048]
# [0.36000721]
# [-16.86367802]
# [-9.62584606]
# [7.01615556]
# [20.60415702]
# [0.69797597]
# [-1.54803547]
# [10.10858759]
# [9.98274867]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.75047462]
# [91.56736822]
# [16.69674061]
# [11.72544587]
# [22.97242218]
# [57.46352753]
# [3.60783048]
# [0.36000721]
# [-16.86367802]
# [-9.62584606]
# [7.01615556]
# [20.60415702]
# [0.69797597]
# [-1.54803547]
# [10.10858759]
# [9.98274867]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.24640699]
# [91.57769398]
# [17.69654335]
# [11.29903398]
# [21.97547208]
# [55.57328027]
# [2.40694533]
# [-0.26625936]
# [-16.04027904]
# [-10.52672405]
# [11.45170742]
# [18.17621025]
# [-1.40804985]
# [-0.54612049]
# [11.29045134]
# [9.50454158]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.24640699]
# [91.57769398]
# [17.69654335]
# [11.29903398]
# [21.97547208]
# [55.57328027]
# [2.40694533]
# [-0.26625936]
# [-16.04027904]
# [-10.52672405]
# [11.45170742]
# [18.17621025]
# [-1.40804985]
# [-0.54612049]
# [11.29045134]
# [9.50454158]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.24640699]
# [91.57769398]
# [17.69654335]
# [11.29903398]
# [21.97547208]
# [55.57328027]
# [2.40694533]
# [-0.26625936]
# [-16.04027904]
# [-10.52672405]
# [11.45170742]
# [18.17621025]
# [-1.40804985]
# [-0.54612049]
# [11.29045134]
# [9.50454158]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.24640699]
# [91.57769398]
# [17.69654335]
# [11.29903398]
# [21.97547208]
# [55.57328027]
# [2.40694533]
# [-0.26625936]
# [-16.04027904]
# [-10.52672405]
# [11.45170742]
# [18.17621025]
# [-1.40804985]
# [-0.54612049]
# [11.29045134]
# [9.50454158]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.24640699]
# [91.57769398]
# [17.69654335]
# [11.29903398]
# [21.97547208]
# [55.57328027]
# [2.40694533]
# [-0.26625936]
# [-16.04027904]
# [-10.52672405]
# [11.45170742]
# [18.17621025]
# [-1.40804985]
# [-0.54612049]
# [11.29045134]
# [9.50454158]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.64332788]
# [91.69814335]
# [16.80349552]
# [12.62916403]
# [21.14295238]
# [52.72436329]
# [1.25908798]
# [-0.92713762]
# [-15.18032229]
# [-10.54403977]
# [15.87082438]
# [14.72259617]
# [-3.39843141]
# [1.37404897]
# [12.49769551]
# [8.52044854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.64332788]
# [91.69814335]
# [16.80349552]
# [12.62916403]
# [21.14295238]
# [52.72436329]
# [1.25908798]
# [-0.92713762]
# [-15.18032229]
# [-10.54403977]
# [15.87082438]
# [14.72259617]
# [-3.39843141]
# [1.37404897]
# [12.49769551]
# [8.52044854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.64332788]
# [91.69814335]
# [16.80349552]
# [12.62916403]
# [21.14295238]
# [52.72436329]
# [1.25908798]
# [-0.92713762]
# [-15.18032229]
# [-10.54403977]
# [15.87082438]
# [14.72259617]
# [-3.39843141]
# [1.37404897]
# [12.49769551]
# [8.52044854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.64332788]
# [91.69814335]
# [16.80349552]
# [12.62916403]
# [21.14295238]
# [52.72436329]
# [1.25908798]
# [-0.92713762]
# [-15.18032229]
# [-10.54403977]
# [15.87082438]
# [14.72259617]
# [-3.39843141]
# [1.37404897]
# [12.49769551]
# [8.52044854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.92324396]
# [91.72159486]
# [15.90206109]
# [12.22723087]
# [22.09027572]
# [48.91738213]
# [0.1630474]
# [0.13456076]
# [-16.04394184]
# [-9.61460482]
# [18.69900898]
# [11.92979822]
# [-3.49963345]
# [2.28276123]
# [12.81846735]
# [8.00347274]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.92324396]
# [91.72159486]
# [15.90206109]
# [12.22723087]
# [22.09027572]
# [48.91738213]
# [0.1630474]
# [0.13456076]
# [-16.04394184]
# [-9.61460482]
# [18.69900898]
# [11.92979822]
# [-3.49963345]
# [2.28276123]
# [12.81846735]
# [8.00347274]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.92324396]
# [91.72159486]
# [15.90206109]
# [12.22723087]
# [22.09027572]
# [48.91738213]
# [0.1630474]
# [0.13456076]
# [-16.04394184]
# [-9.61460482]
# [18.69900898]
# [11.92979822]
# [-3.49963345]
# [2.28276123]
# [12.81846735]
# [8.00347274]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.52718392]
# [91.72159486]
# [16.78756614]
# [11.84991443]
# [23.10947515]
# [44.05270687]
# [0.60633462]
# [-0.30317743]
# [-16.90278579]
# [-7.79415424]
# [21.54220405]
# [8.22869331]
# [-3.55672404]
# [4.06062693]
# [12.23969924]
# [7.84197317]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.52718392]
# [91.72159486]
# [16.78756614]
# [11.84991443]
# [23.10947515]
# [44.05270687]
# [0.60633462]
# [-0.30317743]
# [-16.90278579]
# [-7.79415424]
# [21.54220405]
# [8.22869331]
# [-3.55672404]
# [4.06062693]
# [12.23969924]
# [7.84197317]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.52718392]
# [91.72159486]
# [16.78756614]
# [11.84991443]
# [23.10947515]
# [44.05270687]
# [0.60633462]
# [-0.30317743]
# [-16.90278579]
# [-7.79415424]
# [21.54220405]
# [8.22869331]
# [-3.55672404]
# [4.06062693]
# [12.23969924]
# [7.84197317]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.52718392]
# [91.72159486]
# [16.78756614]
# [11.84991443]
# [23.10947515]
# [44.05270687]
# [0.60633462]
# [-0.30317743]
# [-16.90278579]
# [-7.79415424]
# [21.54220405]
# [8.22869331]
# [-3.55672404]
# [4.06062693]
# [12.23969924]
# [7.84197317]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.9993212]
# [91.68683375]
# [17.71984077]
# [11.61994721]
# [22.03202663]
# [40.19183062]
# [1.13568457]
# [-0.76268668]
# [-16.00575024]
# [-6.85989567]
# [23.67894623]
# [4.34269034]
# [-3.60647079]
# [6.76840965]
# [10.75787511]
# [8.0790838]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.9993212]
# [91.68683375]
# [17.71984077]
# [11.61994721]
# [22.03202663]
# [40.19183062]
# [1.13568457]
# [-0.76268668]
# [-16.00575024]
# [-6.85989567]
# [23.67894623]
# [4.34269034]
# [-3.60647079]
# [6.76840965]
# [10.75787511]
# [8.0790838]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.9993212]
# [91.68683375]
# [17.71984077]
# [11.61994721]
# [22.03202663]
# [40.19183062]
# [1.13568457]
# [-0.76268668]
# [-16.00575024]
# [-6.85989567]
# [23.67894623]
# [4.34269034]
# [-3.60647079]
# [6.76840965]
# [10.75787511]
# [8.0790838]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.9993212]
# [91.68683375]
# [17.71984077]
# [11.61994721]
# [22.03202663]
# [40.19183062]
# [1.13568457]
# [-0.76268668]
# [-16.00575024]
# [-6.85989567]
# [23.67894623]
# [4.34269034]
# [-3.60647079]
# [6.76840965]
# [10.75787511]
# [8.0790838]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.5214854]
# [91.62765213]
# [16.92795969]
# [11.61994721]
# [22.49636813]
# [35.45343607]
# [1.62226467]
# [-1.20159965]
# [-15.11073405]
# [-5.07903864]
# [24.87519267]
# [0.54605695]
# [-3.66748464]
# [10.2382725]
# [8.52765948]
# [8.74971056]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.5214854]
# [91.62765213]
# [16.92795969]
# [11.61994721]
# [22.49636813]
# [35.45343607]
# [1.62226467]
# [-1.20159965]
# [-15.11073405]
# [-5.07903864]
# [24.87519267]
# [0.54605695]
# [-3.66748464]
# [10.2382725]
# [8.52765948]
# [8.74971056]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.5214854]
# [91.62765213]
# [16.92795969]
# [11.61994721]
# [22.49636813]
# [35.45343607]
# [1.62226467]
# [-1.20159965]
# [-15.11073405]
# [-5.07903864]
# [24.87519267]
# [0.54605695]
# [-3.66748464]
# [10.2382725]
# [8.52765948]
# [8.74971056]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.5214854]
# [91.62765213]
# [16.92795969]
# [11.61994721]
# [22.49636813]
# [35.45343607]
# [1.62226467]
# [-1.20159965]
# [-15.11073405]
# [-5.07903864]
# [24.87519267]
# [0.54605695]
# [-3.66748464]
# [10.2382725]
# [8.52765948]
# [8.74971056]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.73635506]
# [91.5583884]
# [16.19790188]
# [11.70753288]
# [22.98581933]
# [31.56685109]
# [0.28632717]
# [0.13433785]
# [-15.98911806]
# [-2.39723557]
# [25.10201005]
# [-1.48417948]
# [-2.77348464]
# [11.01772044]
# [6.27195824]
# [9.93728742]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.73635506]
# [91.5583884]
# [16.19790188]
# [11.70753288]
# [22.98581933]
# [31.56685109]
# [0.28632717]
# [0.13433785]
# [-15.98911806]
# [-2.39723557]
# [25.10201005]
# [-1.48417948]
# [-2.77348464]
# [11.01772044]
# [6.27195824]
# [9.93728742]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.73635506]
# [91.5583884]
# [16.19790188]
# [11.70753288]
# [22.98581933]
# [31.56685109]
# [0.28632717]
# [0.13433785]
# [-15.98911806]
# [-2.39723557]
# [25.10201005]
# [-1.48417948]
# [-2.77348464]
# [11.01772044]
# [6.27195824]
# [9.93728742]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.73635506]
# [91.5583884]
# [16.19790188]
# [11.70753288]
# [22.98581933]
# [31.56685109]
# [0.28632717]
# [0.13433785]
# [-15.98911806]
# [-2.39723557]
# [25.10201005]
# [-1.48417948]
# [-2.77348464]
# [11.01772044]
# [6.27195824]
# [9.93728742]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.25576458]
# [91.5583884]
# [17.07359522]
# [11.7851107]
# [23.51946478]
# [26.67121326]
# [0.80104839]
# [-0.36055468]
# [-16.85676935]
# [1.28270874]
# [24.44325715]
# [-3.59112941]
# [-1.05954694]
# [10.99359148]
# [4.89827102]
# [10.67394579]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.25576458]
# [91.5583884]
# [17.07359522]
# [11.7851107]
# [23.51946478]
# [26.67121326]
# [0.80104839]
# [-0.36055468]
# [-16.85676935]
# [1.28270874]
# [24.44325715]
# [-3.59112941]
# [-1.05954694]
# [10.99359148]
# [4.89827102]
# [10.67394579]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.25576458]
# [91.5583884]
# [17.07359522]
# [11.7851107]
# [23.51946478]
# [26.67121326]
# [0.80104839]
# [-0.36055468]
# [-16.85676935]
# [1.28270874]
# [24.44325715]
# [-3.59112941]
# [-1.05954694]
# [10.99359148]
# [4.89827102]
# [10.67394579]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [66.25576458]
# [91.5583884]
# [17.07359522]
# [11.7851107]
# [23.51946478]
# [26.67121326]
# [0.80104839]
# [-0.36055468]
# [-16.85676935]
# [1.28270874]
# [24.44325715]
# [-3.59112941]
# [-1.05954694]
# [10.99359148]
# [4.89827102]
# [10.67394579]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.83969085]
# [91.53898595]
# [18.06240112]
# [11.73239202]
# [22.09145132]
# [22.80166597]
# [1.30893661]
# [-0.86305887]
# [-15.8866061]
# [4.06835238]
# [22.85147315]
# [-5.70518662]
# [1.55085288]
# [10.0167329]
# [4.47579869]
# [11.03505543]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.83969085]
# [91.53898595]
# [18.06240112]
# [11.73239202]
# [22.09145132]
# [22.80166597]
# [1.30893661]
# [-0.86305887]
# [-15.8866061]
# [4.06835238]
# [22.85147315]
# [-5.70518662]
# [1.55085288]
# [10.0167329]
# [4.47579869]
# [11.03505543]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.83969085]
# [91.53898595]
# [18.06240112]
# [11.73239202]
# [22.09145132]
# [22.80166597]
# [1.30893661]
# [-0.86305887]
# [-15.8866061]
# [4.06835238]
# [22.85147315]
# [-5.70518662]
# [1.55085288]
# [10.0167329]
# [4.47579869]
# [11.03505543]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.47534772]
# [91.40696006]
# [17.18976189]
# [11.73239202]
# [22.5695986]
# [18.01344967]
# [1.80186845]
# [-1.31964037]
# [-14.97190616]
# [7.76235202]
# [20.37605887]
# [-7.85310595]
# [5.05007663]
# [8.17577315]
# [4.98153554]
# [11.01514754]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.47534772]
# [91.40696006]
# [17.18976189]
# [11.73239202]
# [22.5695986]
# [18.01344967]
# [1.80186845]
# [-1.31964037]
# [-14.97190616]
# [7.76235202]
# [20.37605887]
# [-7.85310595]
# [5.05007663]
# [8.17577315]
# [4.98153554]
# [11.01514754]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [65.47534772]
# [91.40696006]
# [17.18976189]
# [11.73239202]
# [22.5695986]
# [18.01344967]
# [1.80186845]
# [-1.31964037]
# [-14.97190616]
# [7.76235202]
# [20.37605887]
# [-7.85310595]
# [5.05007663]
# [8.17577315]
# [4.98153554]
# [11.01514754]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [267.66893748]
# [66.97293068]
# [91.13323099]
# [16.35929483]
# [11.67832984]
# [23.14873881]
# [14.20098481]
# [0.42373662]
# [0.05849146]
# [-15.88275364]
# [12.36348815]
# [16.95599804]
# [-8.12333377]
# [6.64948235]
# [6.36581376]
# [6.45928087]
# [10.56871493]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [267.66893748]
# [66.97293068]
# [91.13323099]
# [16.35929483]
# [11.67832984]
# [23.14873881]
# [14.20098481]
# [0.42373662]
# [0.05849146]
# [-15.88275364]
# [12.36348815]
# [16.95599804]
# [-8.12333377]
# [6.64948235]
# [6.36581376]
# [6.45928087]
# [10.56871493]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [269.15296555]
# [66.52763083]
# [91.13323099]
# [17.20731865]
# [11.54135573]
# [23.76005449]
# [9.54244072]
# [0.86591531]
# [-0.41869965]
# [-15.89252758]
# [17.04363108]
# [12.52639864]
# [-8.36448445]
# [8.28462626]
# [4.56073677]
# [8.89907775]
# [9.66629622]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [269.15296555]
# [66.52763083]
# [91.13323099]
# [17.20731865]
# [11.54135573]
# [23.76005449]
# [9.54244072]
# [0.86591531]
# [-0.41869965]
# [-15.89252758]
# [17.04363108]
# [12.52639864]
# [-8.36448445]
# [8.28462626]
# [4.56073677]
# [8.89907775]
# [9.66629622]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [269.15296555]
# [66.52763083]
# [91.13323099]
# [17.20731865]
# [11.54135573]
# [23.76005449]
# [9.54244072]
# [0.86591531]
# [-0.41869965]
# [-15.89252758]
# [17.04363108]
# [12.52639864]
# [-8.36448445]
# [8.28462626]
# [4.56073677]
# [8.89907775]
# [9.66629622]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [270.56472605]
# [66.20071723]
# [91.00438623]
# [18.20386487]
# [11.26456412]
# [22.65394693]
# [5.72755749]
# [1.32624787]
# [-0.90666465]
# [-14.97243156]
# [19.96605074]
# [8.97173731]
# [-8.59276292]
# [9.93705293]
# [2.72294736]
# [12.27056674]
# [8.17970854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [270.56472605]
# [66.20071723]
# [91.00438623]
# [18.20386487]
# [11.26456412]
# [22.65394693]
# [5.72755749]
# [1.32624787]
# [-0.90666465]
# [-14.97243156]
# [19.96605074]
# [8.97173731]
# [-8.59276292]
# [9.93705293]
# [2.72294736]
# [12.27056674]
# [8.17970854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [270.56472605]
# [66.20071723]
# [91.00438623]
# [18.20386487]
# [11.26456412]
# [22.65394693]
# [5.72755749]
# [1.32624787]
# [-0.90666465]
# [-14.97243156]
# [19.96605074]
# [8.97173731]
# [-8.59276292]
# [9.93705293]
# [2.72294736]
# [12.27056674]
# [8.17970854]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [271.91596259]
# [66.03809122]
# [90.79452494]
# [17.37615291]
# [11.26456412]
# [22.23912696]
# [1.88796921]
# [1.76813982]
# [-1.37747166]
# [-13.14156732]
# [22.89321333]
# [4.48807022]
# [-7.91432052]
# [10.69214465]
# [3.29837681]
# [13.2675263]
# [7.17195505]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [271.91596259]
# [66.03809122]
# [90.79452494]
# [17.37615291]
# [11.26456412]
# [22.23912696]
# [1.88796921]
# [1.76813982]
# [-1.37747166]
# [-13.14156732]
# [22.89321333]
# [4.48807022]
# [-7.91432052]
# [10.69214465]
# [3.29837681]
# [13.2675263]
# [7.17195505]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [271.91596259]
# [66.03809122]
# [90.79452494]
# [17.37615291]
# [11.26456412]
# [22.23912696]
# [1.88796921]
# [1.76813982]
# [-1.37747166]
# [-13.14156732]
# [22.89321333]
# [4.48807022]
# [-7.91432052]
# [10.69214465]
# [3.29837681]
# [13.2675263]
# [7.17195505]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [17.61475606]
# [271.52194275]
# [67.5357855]
# [90.62504079]
# [16.45990301]
# [11.42581673]
# [20.76663074]
# [-0.10674742]
# [0.39452838]
# [-0.00386022]
# [-12.23131932]
# [24.91885006]
# [1.55218549]
# [-7.88397556]
# [10.48130933]
# [4.8451323]
# [13.37054699]
# [6.55539752]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [17.61475606]
# [271.52194275]
# [67.5357855]
# [90.62504079]
# [16.45990301]
# [11.42581673]
# [20.76663074]
# [-0.10674742]
# [0.39452838]
# [-0.00386022]
# [-12.23131932]
# [24.91885006]
# [1.55218549]
# [-7.88397556]
# [10.48130933]
# [4.8451323]
# [13.37054699]
# [6.55539752]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [17.61475606]
# [271.52194275]
# [67.5357855]
# [90.62504079]
# [16.45990301]
# [11.42581673]
# [20.76663074]
# [-0.10674742]
# [0.39452838]
# [-0.00386022]
# [-12.23131932]
# [24.91885006]
# [1.55218549]
# [-7.88397556]
# [10.48130933]
# [4.8451323]
# [13.37054699]
# [6.55539752]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [17.61475606]
# [271.52194275]
# [67.5357855]
# [90.62504079]
# [16.45990301]
# [11.42581673]
# [20.76663074]
# [-0.10674742]
# [0.39452838]
# [-0.00386022]
# [-12.23131932]
# [24.91885006]
# [1.55218549]
# [-7.88397556]
# [10.48130933]
# [4.8451323]
# [13.37054699]
# [6.55539752]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.48137424]
# [271.10092977]
# [67.08621916]
# [90.62504079]
# [17.21877651]
# [11.6783097]
# [18.42929487]
# [-2.15953351]
# [0.87928388]
# [-0.45654724]
# [-10.43127393]
# [25.91438728]
# [-1.26527987]
# [-6.99030585]
# [9.42741079]
# [7.19710666]
# [12.64850203]
# [6.4153137]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.48137424]
# [271.10092977]
# [67.08621916]
# [90.62504079]
# [17.21877651]
# [11.6783097]
# [18.42929487]
# [-2.15953351]
# [0.87928388]
# [-0.45654724]
# [-10.43127393]
# [25.91438728]
# [-1.26527987]
# [-6.99030585]
# [9.42741079]
# [7.19710666]
# [12.64850203]
# [6.4153137]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.48137424]
# [271.10092977]
# [67.08621916]
# [90.62504079]
# [17.21877651]
# [11.6783097]
# [18.42929487]
# [-2.15953351]
# [0.87928388]
# [-0.45654724]
# [-10.43127393]
# [25.91438728]
# [-1.26527987]
# [-6.99030585]
# [9.42741079]
# [7.19710666]
# [12.64850203]
# [6.4153137]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.48137424]
# [271.10092977]
# [67.08621916]
# [90.62504079]
# [17.21877651]
# [11.6783097]
# [18.42929487]
# [-2.15953351]
# [0.87928388]
# [-0.45654724]
# [-10.43127393]
# [25.91438728]
# [-1.26527987]
# [-6.99030585]
# [9.42741079]
# [7.19710666]
# [12.64850203]
# [6.4153137]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [19.48137424]
# [271.10092977]
# [67.08621916]
# [90.62504079]
# [17.21877651]
# [11.6783097]
# [18.42929487]
# [-2.15953351]
# [0.87928388]
# [-0.45654724]
# [-10.43127393]
# [25.91438728]
# [-1.26527987]
# [-6.99030585]
# [9.42741079]
# [7.19710666]
# [12.64850203]
# [6.4153137]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39198709]
# [270.73066719]
# [66.65680362]
# [90.64813646]
# [17.92259135]
# [11.78850711]
# [15.25925136]
# [-4.22485735]
# [1.4074967]
# [-0.92560357]
# [-7.71973576]
# [25.99598892]
# [-4.0907075]
# [-5.17838152]
# [7.48318995]
# [10.46935195]
# [10.93647618]
# [6.85903673]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39198709]
# [270.73066719]
# [66.65680362]
# [90.64813646]
# [17.92259135]
# [11.78850711]
# [15.25925136]
# [-4.22485735]
# [1.4074967]
# [-0.92560357]
# [-7.71973576]
# [25.99598892]
# [-4.0907075]
# [-5.17838152]
# [7.48318995]
# [10.46935195]
# [10.93647618]
# [6.85903673]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39198709]
# [270.73066719]
# [66.65680362]
# [90.64813646]
# [17.92259135]
# [11.78850711]
# [15.25925136]
# [-4.22485735]
# [1.4074967]
# [-0.92560357]
# [-7.71973576]
# [25.99598892]
# [-4.0907075]
# [-5.17838152]
# [7.48318995]
# [10.46935195]
# [10.93647618]
# [6.85903673]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39198709]
# [270.73066719]
# [66.65680362]
# [90.64813646]
# [17.92259135]
# [11.78850711]
# [15.25925136]
# [-4.22485735]
# [1.4074967]
# [-0.92560357]
# [-7.71973576]
# [25.99598892]
# [-4.0907075]
# [-5.17838152]
# [7.48318995]
# [10.46935195]
# [10.93647618]
# [6.85903673]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39198709]
# [270.73066719]
# [66.65680362]
# [90.64813646]
# [17.92259135]
# [11.78850711]
# [15.25925136]
# [-4.22485735]
# [1.4074967]
# [-0.92560357]
# [-7.71973576]
# [25.99598892]
# [-4.0907075]
# [-5.17838152]
# [7.48318995]
# [10.46935195]
# [10.93647618]
# [6.85903673]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39969459]
# [272.14058138]
# [66.22067712]
# [90.74391046]
# [16.85302966]
# [11.78850711]
# [12.99529038]
# [-6.27136748]
# [1.93303446]
# [-1.34988521]
# [-4.12501469]
# [25.13144181]
# [-6.89695545]
# [-3.35229663]
# [7.94239404]
# [12.20310342]
# [8.32700392]
# [7.79330328]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39969459]
# [272.14058138]
# [66.22067712]
# [90.74391046]
# [16.85302966]
# [11.78850711]
# [12.99529038]
# [-6.27136748]
# [1.93303446]
# [-1.34988521]
# [-4.12501469]
# [25.13144181]
# [-6.89695545]
# [-3.35229663]
# [7.94239404]
# [12.20310342]
# [8.32700392]
# [7.79330328]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39969459]
# [272.14058138]
# [66.22067712]
# [90.74391046]
# [16.85302966]
# [11.78850711]
# [12.99529038]
# [-6.27136748]
# [1.93303446]
# [-1.34988521]
# [-4.12501469]
# [25.13144181]
# [-6.89695545]
# [-3.35229663]
# [7.94239404]
# [12.20310342]
# [8.32700392]
# [7.79330328]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [21.39969459]
# [272.14058138]
# [66.22067712]
# [90.74391046]
# [16.85302966]
# [11.78850711]
# [12.99529038]
# [-6.27136748]
# [1.93303446]
# [-1.34988521]
# [-4.12501469]
# [25.13144181]
# [-6.89695545]
# [-3.35229663]
# [7.94239404]
# [12.20310342]
# [8.32700392]
# [7.79330328]
# ...
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [35.31267136]
# [130.974201]
# [67.94989617]
# [12.87609218]
# [29.55510008]
# [41.26178289]
# [16.93366629]
# [55.18312565]
# [11.39846735]
# [17.74312649]
# [99.94979074]
# [26.27127873]
# [25.19671702]
# [229.21961254]
# [75.94509612]
# [31.57404804]
# [12.85071744]
# [-0.34790215]
# [-4.94792695]
# [-13.22736397]
# [-9.45438967]
# [-11.40261035]
# [-0.17803539]
# [-8.63778789]
# [17.65127642]
# [0.56071255]
# [-2.34473266]
# [-12.66368801]
# [-5.34483865]
# [11.08157958]
# [16.58469437]
# [7.12538523]
# [0.11760098]
# [8.5020598]
# [8.1070008]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [34.33435678]
# [132.35540884]
# [66.56868833]
# [13.30170314]
# [29.12948912]
# [41.26178289]
# [17.80041]
# [54.75610742]
# [11.90639602]
# [17.17043699]
# [101.12116283]
# [25.16899802]
# [26.17766577]
# [228.19380035]
# [75.94489475]
# [31.17505686]
# [9.84697675]
# [-1.07804096]
# [-5.4434109]
# [-12.35549575]
# [-8.99089445]
# [-11.40261035]
# [-0.17803539]
# [-7.16066937]
# [16.96196098]
# [-0.22709054]
# [-2.73284764]
# [-12.27557303]
# [-5.75047748]
# [13.68304416]
# [17.50677541]
# [3.9893587]
# [0.13572072]
# [9.78444407]
# [7.13620855]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [33.31435987]
# [131.88805094]
# [66.96968076]
# [13.8810365]
# [28.69665252]
# [41.20112795]
# [18.56409975]
# [54.34290564]
# [12.4448378]
# [16.71111684]
# [100.20471896]
# [26.06763657]
# [25.27902721]
# [229.01924397]
# [75.97999522]
# [30.81959681]
# [5.84660873]
# [-1.79307546]
# [-4.12709243]
# [-13.28244408]
# [-8.54514525]
# [-11.3574087]
# [-0.18452458]
# [-4.73313412]
# [15.29259158]
# [-0.99749353]
# [-3.14208248]
# [-11.88867011]
# [-5.24201873]
# [16.3334096]
# [17.55186737]
# [0.80186395]
# [1.03977064]
# [10.13855116]
# [6.64313212]
# Simulation Halted!
# There was a crash, please retry or consult Tom
# [116.65579221]
# [34.25483889]
# [131.29543049]
# [67.40962646]
# [14.46633885]
# [28.26221837]
# [41.13133454]
# [17.6952207]
# [55.7692758]
# [11.01846764]
# [18.07059885]

# %%
from scipy.interpolate import UnivariateSpline

xData = np.linspace(0,1440,1440)

plt.figure(figsize=(12, 10))
plt.title("Amount of cars per minute for 5 simulations")
plt.xlabel("Minute of Day")
plt.ylabel("Number of Cars")

s = []
xs = []
ys = []
for i in range(len(count_list)):
    plt.plot(xData, count_list[i], linestyle='', marker = 'x')
    s.append(UnivariateSpline(xData, count_list[i], s=13500))
    xs.append(xData)
    ys.append(s[i](xs[i]))
    plt.plot(xs[i], ys[i])

plt.xticks([0,60,120,180,240,300,360,420,480,540,600,660,720,780,840,900,960,1020,1080,1140,1200,1260,1320,1380,1440])
plt.grid(color = 'g')

plt.show()
# Out:
# ..................................................

# %%
import os
import sys
count_list = []
for speeds in range(len(speed_limits)):
    speed_limit = speed_limits[speeds]
    print("Processing speed limit", (speeds+1), "of", len(speed_limits))
    for attempt in range(5):
        cars = []
        counter = 0
        counts = []
        car_count = 0
        create_car(speed_limit, get_length(avg_car))    #Generates an Initial Car
        print((attempt*20), "%")
        for inc in range(len(seconds)):
            new_car_chance = seconds[inc]
            counter = counter + 1    #increments the count variable
            #
            if len(cars) > 0:
                for i in range(len(cars)):    #all cars
                    cars[i].position = cars[i].position + cars[i].speed  #Changes Position
                    cars[i].speed = change_speed(cars[i])    #Changes Speed Randomly
                #
            #
            if len(cars) > 1:
                for i in range(len(cars)-1):
                        cars[i].front, cars[i].speed = check_front(cars[i].position, cars[i+1].position, cars[i+1].length, cars[i].speed, cars[i+1].speed)
                #
                if cars[len(cars)-1].position > tunnel_length:
                    cars.pop(len(cars)-1)
                    car_count = car_count + 1
                #
#                for i in range(len(cars)-1):
#                    if ((cars[i+1].position-cars[i+1].length)-cars[i].position)<0:
#                        print("Simulation Halted!")
#                        print("There was a crash, please retry or consult Tom")
#                        for i in range(len(cars)-1):
#                            print(cars[i+1].position-cars[i+1].length-cars[i].position)
#                        os.startfile('failed.mp3')
#                        sys.exit()
            #
            
            random = np.random.rand(1)    #generates a random number
            if random < new_car_chance:   #compares to the chance of a new car
                create_car(speed_limit, get_length(avg_car))    #generates a new car
            #
            if counter >= 60:
                counts.append(car_count)
                car_count = 0
                counter = 0
            #
        #
        count_list.append(counts)
    #
#
print("Simulation Completed!")
# Out:
# Processing speed limit 1 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 2 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 3 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 4 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 5 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 6 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Processing speed limit 7 of 7
# 0 %
# 20 %
# 40 %
# 60 %
# 80 %
# Simulation Completed!

# %%
from scipy.interpolate import UnivariateSpline

xData = np.linspace(0,1440,1440)

plt.figure(figsize=(12, 10))
plt.title("Amount of cars per minute for 5 simulations")
plt.xlabel("Minute of Day")
plt.ylabel("Number of Cars")

s = []
xs = []
ys = []
for i in range(len(count_list)-30):
    plt.plot(xData, count_list[i], linestyle='', marker = 'x')
    s.append(UnivariateSpline(xData, count_list[i], s=100000))
    xs.append(xData)
    ys.append(s[i](xs[i]))
    plt.plot(xs[i], ys[i])

plt.xticks([0,60,120,180,240,300,360,420,480,540,600,660,720,780,840,900,960,1020,1080,1140,1200,1260,1320,1380,1440])
plt.grid(color = 'g')

plt.show()

# %%
#splitting the array
mph10 = []
mph20 = []
mph30 = []
mph40 = []
mph50 = []
mph60 = []
mph70 = []

for i in range(len(count_list)):
    if i < 5:
        mph10.append(count_list[i])
    elif i < 10:
        mph20.append(count_list[i])
    elif i < 15:
        mph30.append(count_list[i])
    elif i < 20:
        mph40.append(count_list[i])
    elif i < 25:
        mph50.append(count_list[i])
    elif i < 30:
        mph60.append(count_list[i])
    elif i < 35:
        mph70.append(count_list[i])
print(len(mph10), len(mph60))
mph10avg, mph20avg, mph30avg, mph40avg, mph50avg, mph60avg, mph70avg = [],[],[],[],[],[],[]
for i in range(len(mph10[0])):
    mph10avg.append(mph10[0][i]+mph10[1][i]+mph10[2][i]+mph10[3][i]+mph10[4][i])
    mph20avg.append(mph20[0][i]+mph20[1][i]+mph20[2][i]+mph20[3][i]+mph20[4][i])
    mph30avg.append(mph30[0][i]+mph30[1][i]+mph30[2][i]+mph30[3][i]+mph30[4][i])
    mph40avg.append(mph40[0][i]+mph40[1][i]+mph40[2][i]+mph40[3][i]+mph40[4][i])
    mph50avg.append(mph50[0][i]+mph50[1][i]+mph50[2][i]+mph50[3][i]+mph50[4][i])
    mph60avg.append(mph60[0][i]+mph60[1][i]+mph60[2][i]+mph60[3][i]+mph60[4][i])
    mph70avg.append(mph70[0][i]+mph70[1][i]+mph70[2][i]+mph70[3][i]+mph70[4][i])
#
print(len(mph10avg))
mph10avg, mph20avg, mph30avg, mph40avg, mph50avg, mph60avg, mph70avg = np.array(mph10avg), np.array(mph20avg), np.array(mph30avg), np.array(mph40avg), np.array(mph50avg), np.array(mph60avg), np.array(mph70avg)
mph10avg, mph20avg, mph30avg, mph40avg, mph50avg, mph60avg, mph70avg = mph10avg/5, mph20avg/5, mph30avg/5, mph40avg/5, mph50avg/5, mph60avg/5, mph70avg/5
print(mph10avg)
# Out:
# 5 5
# 1440
# [0.  0.  0.  ... 6.6 5.2 6.4]

# %%
from scipy.interpolate import UnivariateSpline
plot_data = False
xData = np.linspace(0,1440,1440)

plt.figure(figsize=(12, 10))
plt.title("Amount of cars per minute for 5 simulations for each speed")
plt.xlabel("Minute of Day")
plt.ylabel("Number of Cars")

if plot_data:
    plt.plot(xData, mph10avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph10avg, s=27500))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="10mph")

if plot_data:
    plt.plot(xData, mph20avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph20avg, s=1900))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="20mph")

if plot_data:
    plt.plot(xData, mph30avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph30avg, s=2400))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="30mph")

if plot_data:
    plt.plot(xData, mph40avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph40avg, s=2400))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="40mph")

if plot_data:
    plt.plot(xData, mph50avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph50avg, s=2500))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="50mph")

if plot_data:
    plt.plot(xData, mph60avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph60avg, s=2500))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="60mph")

if plot_data:
    plt.plot(xData, mph70avg, linestyle='', marker = 'x')
s=(UnivariateSpline(xData, mph70avg, s=2500))
xs=(xData)
ys=(s(xs))
plt.plot(xs, ys, label="70mph")

plt.xticks([0,60,120,180,240,300,360,420,480,540,600,660,720,780,840,900,960,1020,1080,1140,1200,1260,1320,1380,1440])
plt.grid(color = 'g')
plt.legend()
plt.savefig('7 Speeds - 5 Runs')
plt.show()

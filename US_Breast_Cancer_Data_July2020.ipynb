# %%
import pandas as pd

# %%
data = pd.read_pickle("/mnt/b/Google_Drive/PhD/DataSets/BRC961.pickle")

# %%
data.index.names
# Out:
# FrozenList(['Core', 'Label', 'No.', 'Age', 'Sex', 'Organ', 'Pathology', 'TNM', 'Grade', 'Stage', 'Type', 'Tissue ID.', 'AR', 'ER', 'PR', 'HER2', 'Region Label', 'TMA'])

# %%
data.head()
# Out:
#                                                                                                                            BRC961  0.027041
#                                                                                                                               BRC961  0.031529
#                                                                                                                               BRC961  0.028141
#                                                                                                                               BRC961  0.034594
#
#                                                                                                                                         754.0   \
# Core Label No. Age Sex Organ  Pathology    TNM Grade Stage Type   Tissue ID. AR     ER          PR          HER2 Region Label TMA
# ...

# %%
data.groupby("AR").mean().T.plot()

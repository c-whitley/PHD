# %%
# %load_ext autoreload

# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os.path

file_place = r"C:\Users\Conor\DataSets"

Breast_DF = pd.read_pickle(os.path.join(file_place,"Breast_data_raw"))

# %%
Breast_DF.head()
# Out:
#                                                                         912   \
# Sex Type      Stage Pathology                 Grade Label Age Core
# F   Malignant IIa   Invasive ductal carcinoma 1     Blood 40  B4    0.094676
#                                                               B4    0.094676
#                                                               B4    0.095110
#                                                               B4    0.095979
#                                                               B4    0.097282
#
#                                                                         916   \
# Sex Type      Stage Pathology                 Grade Label Age Core
# F   Malignant IIa   Invasive ductal carcinoma 1     Blood 40  B4    0.093373
#                                                               B4    0.093808
#                                                               B4    0.093808
# ...

# %%
from sklearn.model_selection import train_test_split

X = Breast_DF.values
Y = Breast_DF.reset_index()["Type"]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from scipy.stats import gaussian_kde

# %%
# %%time

from MA_Classifier import MA_classifier

MA = MA_classifier()
MA.fit(X_train, y_train)
# Out:
# Wall time: 1min 5s

# %%
plt.clf()
plt.plot(X_test[3])
plt.show()

# %%
predictions = MA.predict(X_test[0])

predictions["Prediction"] = predictions.idxmax(axis = 1)

# %%
predictions
# Out:
#      Malignant           NAT    Normal Prediction
# 0     0.676051  2.317905e-05  0.018303  Malignant
# 1     0.645855  2.160199e-05  0.018062  Malignant
# 2     0.674046  2.674657e-05  0.018294  Malignant
# 3     0.733345  3.555778e-05  0.018083  Malignant
# 4     0.813658  7.142630e-05  0.021011  Malignant
# 5     0.805137  8.376113e-05  0.024593  Malignant
# 6     0.870717  1.244788e-04  0.034490  Malignant
# 7     0.928195  2.035983e-04  0.041730  Malignant
# 8     0.945981  2.194297e-04  0.039857  Malignant
# 9     0.957805  2.037980e-04  0.033267  Malignant
# 10    0.878053  1.283405e-04  0.022440  Malignant
# 11    0.908565  1.345872e-04  0.024164  Malignant
# 12    0.871718  1.275418e-04  0.025292  Malignant
# 13    0.787821  1.102167e-04  0.024123  Malignant
# 14    0.801031  1.344859e-04  0.023737  Malignant
# 15    0.777423  1.327528e-04  0.019935  Malignant
# 16    0.842502  1.770287e-04  0.023272  Malignant
# 17    0.836612  1.392925e-04  0.021812  Malignant
# ...

# %%
predictions.plot()
